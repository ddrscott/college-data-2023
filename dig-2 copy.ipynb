# %% [markdown]
# ## Setup

# %%
import duckdb

conn = duckdb.connect('data/duck.db')
conn.sql("""\
INSTALL spatial;
LOAD spatial;
         
INSTALL vss;
LOAD vss;
         
SET hnsw_enable_experimental_persistence = true;
""")


from IPython.core.magic import (register_line_magic, register_cell_magic, register_line_cell_magic, needs_local_scope)
from IPython.core.magic_arguments import (argument, magic_arguments, parse_argstring)

@magic_arguments()
@argument('query', nargs='*', help="The SQL query to execute")
@argument('--db', '-d', default=None, help="Which connection to use")
@argument('--output', '-o', default=None, help="Name of the variable to store output DataFrame in local scope")
@register_line_cell_magic
@needs_local_scope
def quack(line, cell=None, local_ns=None):
    "Magic that works both as %lcmagic and as %%lcmagic"

    args = parse_argstring(quack, line)
    query = cell if cell else ' '.join(args.query)

    if args.db:
        conn = local_ns[args.db]
    elif 'conn' in local_ns:
        conn = local_ns['conn']
    else:
        
        conn = duckdb.connect(':memory:')
        local_ns['conn'] = conn

    result = conn.sql(query)
    
    if args.output:
        local_ns[args.output] = result
    return result

# %%
import ollama
from typing import Optional

def embeddings(prompt:str) -> list[float]:
    result = ollama.embeddings(model='mxbai-embed-large', prompt=prompt)
    return result.embedding

embeds = embeddings("The quick brown fox jumps over the lazy dog.")
print('Embedding Size: ', len(embeds))
# Out:
# Embedding Size:  1024

# %%
try:
    conn.remove_function("embeddings")
except:
    # probably didn't exist
    pass

conn.create_function("embeddings", embeddings)

conn.sql(r"""
drop table if exists foo;
create table foo as
    SELECT embeddings('Arizona State University') as embedding;
""")
conn.sql("select * from foo")
# Out:
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [0.6846265196800232, 0.4564392864704132, 0.04044051840901375, -0.10063144564628601, -0.46283653378486633, 0.05508655309677124, -0.7959083318710327, 0.11123457551002502, 0.43675723671913147, 0.9380875825881958, 0.5064622163772583, -0.5997560024261475, 0.8160062432289124, -0.030596286058425903, 0.10243459045886993, 0.8379154205322266, 0.18711622059345245, -0.7218776345252991, -1.194055438041687, 0.16635233163833618, -0.4752458930015564, 0.4644261300563812, -1.5731697082519531, 0.28864288330078125, 0.3298488259315491, -0.15070798993110657, -0.1669229418039322, -0.1494765430688858, 0.9600115418434143, 0.7918040752410889, -0.30368560552597046, -0.273785263299942, 0.05322755128145218, -0.9063124656677246, 0.05851055681705475, -0.40580588579177856, 0.16465215384960175, -0.6439034938812256, -0.526128888130188, -0.3696194291114807, 0.7060596346855164, 0.1472778469324112, 0.6508780121803284, -0.8285205364227295, -1.2388520240783691, -0.02103034406900406, -0.3671554625034332, -0.9926990866661072, -0.14161348342895508, 0.18486031889915466, -0.04301317036151886, 0.8022151589393616, 0.9423187375068665, -0.03011109121143818, 0.5623032450675964, 0.16969527304172516, -0.1293884515762329, 0.07894991338253021, 0.08907537162303925, 0.16777265071868896, 0.8814380168914795, 0.2824057340621948, -0.2278011292219162, -1.0932953357696533, 0.12519274652004242, 0.7151983976364136, 0.22324371337890625, 0.02481009066104889, 0.35238218307495117, -0.34032952785491943, -0.08994905650615692, 0.23144622147083282, -0.3588569164276123, -0.037187620997428894, -1.244086503982544, 0.33029237389564514, -0.1945604383945465, 0.5702897310256958, 0.3108428418636322, -0.5354065895080566, 0.681071400642395, 0.12679383158683777, 0.24042658507823944, -0.0599091574549675, 0.06467768549919128, -0.30266743898391724, -0.2735725939273834, 0.09839119762182236, 0.1615789830684662, 0.32259097695350647, -0.48157453536987305, 0.9289076924324036, -0.1725253462791443, -0.2860538363456726, 0.1706196665763855, 0.4231787323951721, 0.17755240201950073, 0.18658515810966492, 0.581383466720581, -0.36466264724731445, 0.5977310538291931, 0.31174829602241516, -0.15199606120586395, 1.153498649597168, -0.3448651432991028, 0.3487168550491333, -0.41285771131515503, -0.41883584856987, 0.25542834401130676, -0.5536159873008728, -0.19244089722633362, 0.026279259473085403, -0.4531749486923218, 0.25962042808532715, -1.0433707237243652, 0.7659013271331787, 0.577089250087738, 0.5976019501686096, -0.8893923163414001, -0.44467052817344666, 0.18230019509792328, 0.39526206254959106, 0.26566582918167114, 0.5315476059913635, -0.4293157458305359, -0.20141816139221191, -0.8452637195587158, 0.6319187879562378, 0.20116151869297028, -0.009110048413276672, 0.007867910899221897, -0.12375421822071075, -0.5962104201316833, 0.7859148979187012, 0.40495961904525757, -0.05197107046842575, 1.1990634202957153, 0.25452759861946106, 0.40392354130744934, -0.7280687689781189, -0.184642493724823, 0.8826088309288025, -0.20725387334823608, 1.2648605108261108, 0.14510200917720795, 0.6086909770965576, -0.283174604177475, 0.44969695806503296, -0.7597203850746155, -0.05987636744976044, -1.3625917434692383, 0.3147841989994049, -0.16541188955307007, 0.14956949651241302, -0.032460376620292664, 0.3529834449291229, 0.5674586296081543, 0.713654100894928, -0.5728206038475037, -0.20484530925750732, -0.8729122281074524, -0.34978190064430237, -0.6605831384658813, 0.577022910118103, 0.26201555132865906, 0.2785033583641052, 0.09112073481082916, 0.07257440686225891, 0.03848375007510185, -0.23317520320415497, 0.25612401962280273, 0.40050750970840454, -0.21976855397224426, 0.7594437003135681, 0.11456388235092163, -0.22696572542190552, 0.26939982175827026, 0.28639844059944153, -0.5394273996353149, 0.4968264102935791, -0.32805800437927246, -0.21584558486938477, -0.23703889548778534, 1.0855977535247803, 0.06883402168750763, -0.10334137827157974, -0.19795778393745422, -0.5857018828392029, -0.09921837598085403, -0.0737808495759964, -0.2241382747888565, 0.57 ...
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...

# %%
import pandas as pd
import json

def utr_data():
    data = json.loads(open('data/utr-mens.json').read())
    hits = pd.json_normalize(data['hits'])
    utr = pd.DataFrame()

    fields = [
        'id',
        'source.school.name',
        'source.school.shortName',
        'source.school.power6',
        'source.school.power6High',
        'source.school.power6Low',
        'source.school.conference.division.divisionName',
        'source.location.latLng',
        'source.location.cityName',
        'source.location.stateAbbr',
        'source.url',
        'source.memberCount',
    ]
    for field in fields:
        last_field = field.split('.')[-1]
        utr[last_field] = hits[field]

    return utr

utr = utr_data()

conn.sql(r"""
DROP TABLE IF EXISTS utr_vec;
CREATE TABLE utr_vec AS
SELECT
    utr.*,
    embeddings(concat(utr.name, (case when utr.shortName is not null then concat(' (', utr.shortName, ') ') else '' end), ', location: ', utr.cityName, ', ', utr.stateAbbr, ', ', utr.url))::float[1024] AS vectors
FROM utr
""")
conn.sql(r"""
SELECT COUNT(*) AS "Total utr_vec Records" FROM utr_vec
""")
# Out:
# ┌───────────────────────┐
# │ Total utr_vec Records │
# │         int64         │
# ├───────────────────────┤
# │                   956 │
# └───────────────────────┘

# %%
schools = pd.read_csv('data/hd2023.csv', encoding='latin1')
charges = pd.read_csv('data/ic2023_ay.csv', encoding='latin1')

costs = conn.sql(r"""
SELECT
    schools.unitid as college_id,
    trim(INSTNM) AS college_name,
    trim(IALIAS) AS short_name,
    regexp_replace(regexp_replace(college_name, '(-.+?ampus$)|(^The )', '', 'g'), '\sat\W(.*)$', ' (\1)') as join_name,
    city AS city,
    stabbr AS state,
    LATITUDE::float as latitude,
    LONGITUD::float as longitude,
    WEBADDR AS url,
    try_cast(CHG3AY3 AS DECIMAL(10,2)) AS total_cost
FROM schools
JOIN charges ON schools.UNITID = charges.UNITID
""")

costs.to_df().to_csv(path_or_buf='data/school_costs.csv', index=False)

conn.sql(r"""
DROP TABLE IF EXISTS costs_vec;
CREATE TABLE costs_vec AS
SELECT
    costs.*,
    embeddings(concat(college_name, (case when short_name is not null then concat(' (', short_name, ') ') else '' end), ', location: ', city, ', ', state, ', ', url))::float[1024] AS vectors,
    null::int as utr_id
FROM costs
""")
conn.sql(r"""
SELECT COUNT(*) as "Total costs_vec Records" FROM costs_vec
""")
# Out:
# ┌─────────────────────────┐
# │ Total costs_vec Records │
# │          int64          │
# ├─────────────────────────┤
# │                    3825 │
# └─────────────────────────┘

# %%
# %%quack
# select * from utr_vec where vectors is null;
# Out:
# ┌─────────┬─────────┬───────────┬────────┬────────────┬───────────┬──────────────┬──────────┬──────────┬───────────┬─────────┬─────────────┬─────────────┐
# │   id    │  name   │ shortName │ power6 │ power6High │ power6Low │ divisionName │  latLng  │ cityName │ stateAbbr │   url   │ memberCount │   vectors   │
# │ varchar │ varchar │  varchar  │ double │   double   │  double   │   varchar    │ double[] │ varchar  │  varchar  │ varchar │    int64    │ float[1024] │
# ├─────────┴─────────┴───────────┴────────┴────────────┴───────────┴──────────────┴──────────┴──────────┴───────────┴─────────┴─────────────┴─────────────┤
# │                                                                         0 rows                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%quack
# create index cost_vec_idx on costs_vec using hnsw (vectors);
# create index utr_vec_idx on utr_vec using hnsw (vectors);

# %%
# %%quack
#
# update costs_vec set utr_id = 1345 where college_id = 110680;
# -- 110680 │ University of California-San Diego   │ La Jolla       │ CA      │  32.87775 │ -117.23586 │ www.ucsd.edu/                 │      46042.00 │   NULL │      0.12578559 │ 1345    │ UC San Diego                      │ NULL          │  70.13 │      12.34 │     11.26 │ NCAA - Division I   │ [32.715738, -117.1610838]               │ San Diego      │ CA        │ NULL                                                │         125 │     NULL │          3 │

# %% [markdown]
# ## Test out `array_cosine_distance` to find similar vectors. 0 = no difference, 1 = very different

# %%
# %%quack
#
# select
#     utr_vec.* exclude (vectors),
#     '|' as "|",
#     array_cosine_distance(utr_vec.vectors, costs_vec.vectors)::float as cosine_distance,
#     costs_vec.* exclude (vectors)
# from utr_vec
# full join costs_vec on stateAbbr = state
# where id in (2803, 2383)
#   and array_cosine_distance(utr_vec.vectors, costs_vec.vectors) < 0.3
#   and utr_id is null
# order by name, array_cosine_distance(utr_vec.vectors, costs_vec.vectors)::float asc
# ;
# Out:
# ┌─────────┬─────────────────────────────────┬─────────────┬────────┬────────────┬───────────┬─────────────────────┬──────────────────────────────────┬──────────────┬───────────┬─────────┬─────────────┬────────┬─────────┬─────────────────┬────────────┬─────────────────────────────────┬────────────┬─────────────────────────────────┬───────────────────┬─────────┬───────────┬────────────┬─────────────────────────────────────┬───────────────┐
# │   id    │              name               │  shortName  │ power6 │ power6High │ power6Low │    divisionName     │              latLng              │   cityName   │ stateAbbr │   url   │ memberCount │ utr_id │    |    │ cosine_distance │ college_id │          college_name           │ short_name │            join_name            │       city        │  state  │ latitude  │ longitude  │                 url                 │  total_cost   │
# │ varchar │             varchar             │   varchar   │ double │   double   │  double   │       varchar       │             double[]             │   varchar    │  varchar  │ varchar │    int64    │ int32  │ varchar │      float      │   int64    │             varchar             │  varchar   │             varchar             │      varchar      │ varchar │   float   │   float    │               varchar               │ decimal(10,2) │
# ├─────────┼─────────────────────────────────┼─────────────┼────────┼────────────┼───────────┼─────────────────────┼──────────────────────────────────┼──────────────┼───────────┼─────────┼─────────────┼────────┼─────────┼─────────────────┼────────────┼─────────────────────────────────┼────────────┼─────────────────────────────────┼───────────────────┼─────────┼───────────┼────────────┼─────────────────────────────────────┼───────────────┤
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │      0.24588501 │     231165 │ Vermont State University        │            │ Vermont State University        │ Randolph          │ VT      │ 43.939625 │   -72.6045 │ vermontstate.edu/                   │      21408.00 │
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │      0.26211494 │     230852 │ Champlain College               │            │ Champlain College               │ Burlington        │ VT      │ 44.473286 │  -73.20274 │ www.champlain.edu/                  │      45550.00 │
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │       0.2898084 │     230889 │ Goddard College                 │            │ Goddard College                 │ Plainfield        │ VT      │ 44.279087 │ -72.438385 │ www.goddard.edu/                    │      19568.00 │
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │      0.29470778 │     231095 │ Sterling College                │            │ Sterling College                │ Craftsbury Common │ VT      │  44.65225 │  -72.38237 │ www.sterlingcollege.edu/            │      40760.00 │
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │      0.29517448 │     230959 │ Middlebury College              │            │ Middlebury College              │ Middlebury        │ VT      │ 44.009117 │  -73.17607 │ https://www.middlebury.edu/college/ │      65280.00 │
# │ 2383    │ Johnson State College           │ NULL        │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [44.6400507, -72.66150809999999] │ East Johnson │ VT        │ NULL    │           4 │   NULL │ |       │      0.29952353 │     231174 │ University of Vermont           │ UVM        │ University of Vermont           │ Burlington        │ VT      │ 44.477325 │  -73.19665 │ www.uvm.edu/                        │      43890.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │     0.121783674 │     231165 │ Vermont State University        │            │ Vermont State University        │ Randolph          │ VT      │ 43.939625 │   -72.6045 │ vermontstate.edu/                   │      21408.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.17828536 │     231174 │ University of Vermont           │ UVM        │ University of Vermont           │ Burlington        │ VT      │ 44.477325 │  -73.19665 │ www.uvm.edu/                        │      43890.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.24848914 │     230889 │ Goddard College                 │            │ Goddard College                 │ Plainfield        │ VT      │ 44.279087 │ -72.438385 │ www.goddard.edu/                    │      19568.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.24885213 │     230995 │ Norwich University              │            │ Norwich University              │ Northfield        │ VT      │ 44.140236 │  -72.65978 │ www.norwich.edu/                    │      49600.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │       0.2523334 │     230852 │ Champlain College               │            │ Champlain College               │ Burlington        │ VT      │ 44.473286 │  -73.20274 │ www.champlain.edu/                  │      45550.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.26979697 │     230861 │ Community College of Vermont    │ CCV        │ Community College of Vermont    │ Montpelier        │ VT      │  44.28081 │  -72.57378 │ www.ccv.edu/                        │      13640.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.27168137 │     231095 │ Sterling College                │            │ Sterling College                │ Craftsbury Common │ VT      │  44.65225 │  -72.38237 │ www.sterlingcollege.edu/            │      40760.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │       0.2724169 │     230816 │ Bennington College              │ Bennington │ Bennington College              │ Bennington        │ VT      │ 42.919548 │   -73.2378 │ https://www.bennington.edu/         │      64644.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.27780217 │     230959 │ Middlebury College              │            │ Middlebury College              │ Middlebury        │ VT      │ 44.009117 │  -73.17607 │ https://www.middlebury.edu/college/ │      65280.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │      0.28263122 │     231147 │ Vermont Law and Graduate School │ VLGS       │ Vermont Law and Graduate School │ South Royalton    │ VT      │ 43.821407 │  -72.52092 │ www.vermontlaw.edu/                 │          NULL │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │       0.2840932 │     231059 │ Saint Michael's College         │            │ Saint Michael's College         │ Colchester        │ VT      │ 44.494556 │  -73.16707 │ www.smcvt.edu/                      │      50040.00 │
# │ 2803    │ Vermont State University Lyndon │ VTSU Lyndon │  19.63 │       5.57 │       1.0 │ NCAA - Division III │ [44.5336665, -72.0031513]        │ Lyndon       │ VT        │ NULL    │           4 │   NULL │ |       │       0.2871998 │     455992 │ Vermont College of Fine Arts    │ VCFA       │ Vermont College of Fine Arts    │ Montpelier        │ VT      │  44.25521 │  -72.56762 │ www.vcfa.edu/                       │          NULL │
# ├─────────┴─────────────────────────────────┴─────────────┴────────┴────────────┴───────────┴─────────────────────┴──────────────────────────────────┴──────────────┴───────────┴─────────┴─────────────┴────────┴─────────┴─────────────────┴────────────┴─────────────────────────────────┴────────────┴─────────────────────────────────┴───────────────────┴─────────┴───────────┴────────────┴─────────────────────────────────────┴───────────────┤
# │ 18 rows                                                                                                                                                                                                                                                                                                                                                                                                                                    25 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%quack
# -- reset all the UTR assignments
# UPDATE costs_vec SET utr_id = null;

# %%
# %%quack
#
# WITH matches AS (
#     SELECT
#         DISTINCT ON (college_id)
#         costs_vec.* exclude (vectors),
#         array_cosine_distance(utr_vec.vectors, costs_vec.vectors)::float as cosine_distance,
#         utr_vec.* exclude (vectors),
#         '|' as "|",
#     FROM costs_vec
#     LEFT JOIN utr_vec on stateAbbr = state
#     WHERE  array_cosine_distance(utr_vec.vectors, costs_vec.vectors) < 0.07
#       AND costs_vec.utr_id IS NULL
#     ORDER BY college_id, array_cosine_distance(utr_vec.vectors, costs_vec.vectors)::float asc
# )
# UPDATE costs_vec SET
#     utr_id = matches.id
# FROM matches
# WHERE costs_vec.college_id = matches.college_id
# ;

# %%
# %%quack
#
# WITH
# unassigned_utr AS (
#     SELECT
#         utr_vec.*
#     FROM utr_vec
#     LEFT JOIN costs_vec on costs_vec.utr_id = utr_vec.id
#     WHERE costs_vec.utr_id IS NULL
# ),
# matches AS (
#     SELECT
#         DISTINCT ON (college_id)
#         costs_vec.* exclude (vectors),
#         array_cosine_distance(utr.vectors, costs_vec.vectors)::float as cosine_distance,
#         utr.* exclude (vectors)
#     FROM costs_vec
#     LEFT JOIN unassigned_utr AS utr on stateAbbr = state
#     WHERE  array_cosine_distance(utr.vectors, costs_vec.vectors) < 0.09
#       AND costs_vec.utr_id IS NULL
#     ORDER BY college_id, array_cosine_distance(utr.vectors, costs_vec.vectors)::float asc
# ),
# counts as (
#     select
#         name,
#         count(1)
#     from matches
#     group by 1
#     having count(1) > 1
# )
# UPDATE costs_vec SET
#     utr_id = matches.id
# FROM matches
# WHERE costs_vec.college_id = matches.college_id
# ;

# %%
# %%quack
#
# WITH
# unassigned_utr AS (
#     SELECT
#         utr_vec.*
#     FROM utr_vec
#     LEFT JOIN costs_vec on costs_vec.utr_id = utr_vec.id
#     WHERE costs_vec.utr_id IS NULL
# ),
# matches AS (
#     SELECT
#         DISTINCT ON (college_id)
#         costs_vec.* exclude (vectors),
#         array_cosine_distance(utr.vectors, costs_vec.vectors)::float as cosine_distance,
#         utr.* exclude (vectors)
#     FROM costs_vec
#     LEFT JOIN unassigned_utr AS utr on stateAbbr = state
#     WHERE  array_cosine_distance(utr.vectors, costs_vec.vectors) < 0.125
#       AND costs_vec.utr_id IS NULL
#     ORDER BY college_id, array_cosine_distance(utr.vectors, costs_vec.vectors)::float asc
# ),
# counts as (
#     select
#         * exclude(short_name, join_name),
#         count(college_id) over (partition by name) as name_count
#     from matches
# )
# UPDATE costs_vec SET
#     utr_id = matches.id
# FROM matches
# WHERE costs_vec.college_id = matches.college_id
# ;

# %%
# %%quack
#
# WITH
# unassigned_utr AS (
#     SELECT
#         utr_vec.*
#     FROM utr_vec
#     LEFT JOIN costs_vec on costs_vec.utr_id = utr_vec.id
#     WHERE costs_vec.utr_id IS NULL
# ),
# matches AS (
#     SELECT
#         DISTINCT ON (college_id)
#         costs_vec.* exclude (vectors),
#         array_cosine_distance(utr.vectors, costs_vec.vectors)::float as cosine_distance,
#         utr.* exclude (vectors)
#     FROM costs_vec
#     LEFT JOIN unassigned_utr AS utr on stateAbbr = state
#     WHERE  array_cosine_distance(utr.vectors, costs_vec.vectors) < 0.15
#       AND costs_vec.utr_id IS NULL
#     ORDER BY college_id, array_cosine_distance(utr.vectors, costs_vec.vectors)::float asc
# ),
# counts as (
#     select
#         * exclude(short_name, join_name),
#         count(college_id) over (partition by name) as name_count
#     from matches
# )
# select * from counts order by name_count desc, name;
# ;
# Out:
# ┌────────────┬──────────────────────────────────────┬────────────────┬─────────┬───────────┬────────────┬────────────────────────────────┬───────────────┬────────┬─────────────────┬─────────┬───────────────────────────────────┬───────────────┬────────┬────────────┬───────────┬─────────────────────┬─────────────────────────────────────────┬────────────────┬───────────┬─────────────────────────────────────────────────────┬─────────────┬──────────┬────────────┐
# │ college_id │             college_name             │      city      │  state  │ latitude  │ longitude  │              url               │  total_cost   │ utr_id │ cosine_distance │   id    │               name                │   shortName   │ power6 │ power6High │ power6Low │    divisionName     │                 latLng                  │    cityName    │ stateAbbr │                        url_1                        │ memberCount │ utr_id_1 │ name_count │
# │   int64    │               varchar                │    varchar     │ varchar │   float   │   float    │            varchar             │ decimal(10,2) │ int32  │      float      │ varchar │              varchar              │    varchar    │ double │   double   │  double   │       varchar       │                double[]                 │    varchar     │  varchar  │                       varchar                       │    int64    │  int32   │   int64    │
# ├────────────┼──────────────────────────────────────┼────────────────┼─────────┼───────────┼────────────┼────────────────────────────────┼───────────────┼────────┼─────────────────┼─────────┼───────────────────────────────────┼───────────────┼────────┼────────────┼───────────┼─────────────────────┼─────────────────────────────────────────┼────────────────┼───────────┼─────────────────────────────────────────────────────┼─────────────┼──────────┼────────────┤
# │     100654 │ Alabama A & M University             │ Normal         │ AL      │ 34.783367 │ -86.568504 │ www.aamu.edu/                  │      18634.00 │   NULL │      0.14485985 │ 1473    │ Alabama A&M University            │ Alabama A&M   │  63.29 │      11.34 │      8.67 │ NCAA - Division I   │ [34.7303688, -86.5861037]               │ Huntsville     │ AL        │ http://www.aamusports.com/index.aspx?path=mten      │          33 │     NULL │          1 │
# │     164465 │ Amherst College                      │ Amherst        │ MA      │  42.37246 │  -72.51849 │ www.amherst.edu/               │      67280.00 │   NULL │      0.12609804 │ 1312    │ Amherst College                   │ NULL          │  67.43 │       11.7 │     10.89 │ NCAA - Division III │ [42.3732216, -72.5198537]               │ Amherst        │ MA        │ http://athletics.amherst.edu/sports/mten/index      │         102 │     NULL │          1 │
# │     156286 │ Bellarmine University                │ Louisville     │ KY      │  38.21928 │ -85.704994 │ https://www.bellarmine.edu/    │      47180.00 │   NULL │      0.13243687 │ 1465    │ Bellarmine University             │ NULL          │  69.63 │      12.31 │     11.03 │ NCAA - Division I   │ [38.2468618, -85.7663724]               │ Louisville     │ KY        │ https://athletics.bellarmine.edu/sports/mens-tennis │          50 │     NULL │          1 │
# │     219709 │ Belmont University                   │ Nashville      │ TN      │  36.13559 │  -86.79481 │ https://www.belmont.edu/       │      41320.00 │   NULL │      0.14304113 │ 1075    │ Belmont University                │ Belmont       │  69.77 │      12.03 │     11.22 │ NCAA - Division I   │ [36.1305357, -86.79359099999999]        │ Nashville      │ TN        │ http://belmontbruins.com/sports/m-tennis/index      │         466 │     NULL │          1 │
# │     164924 │ Boston College                       │ Chestnut Hill  │ MA      │ 42.336212 │  -71.16924 │ www.bc.edu/                    │      67680.00 │   NULL │      0.14112043 │ 1325    │ Boston College                    │ NULL          │  68.64 │       12.3 │     10.71 │ NCAA - Division I   │ [42.3370413, -71.20922139999999]        │ Newton         │ MA        │ http://bceagles.com/index.aspx?path=mten            │         129 │     NULL │          1 │
# │     110413 │ California Lutheran University       │ Thousand Oaks  │ CA      │ 34.224567 │ -118.87892 │ www.callutheran.edu/           │      50670.00 │   NULL │      0.13859266 │ 2235    │ California Lutheran University    │ NULL          │  57.01 │      10.26 │      8.89 │ NCAA - Division III │ [34.1761133, -118.8487793]              │ Thousand Oaks  │ CA        │ http://www.clusports.com/mens_tennis/               │          49 │     NULL │          1 │
# │     153108 │ Central College                      │ Pella          │ IA      │  41.40154 │ -92.922195 │ www.central.edu/               │      20988.00 │   NULL │      0.14140469 │ 2534    │ Central College                   │ NULL          │  44.84 │       8.58 │      6.77 │ NCAA - Division III │ [41.4080327, -92.91640500000001]        │ Pella          │ IA        │ https://athletics.central.edu/sports/mens-tennis    │          37 │     NULL │          1 │
# │     211024 │ Clarks Summit University             │ Clarks Summit  │ PA      │ 41.495064 │  -75.68547 │ https://www.clarkssummitu.edu/ │      32400.00 │   NULL │      0.13944894 │ 3025    │ Clarks Summit University          │ NULL          │  19.11 │       4.22 │      1.44 │ NCAA - Division III │ [41.4806912, -75.6848074]               │ NULL           │ PA        │ NULL                                                │           3 │     NULL │          1 │
# │     190558 │ College of Staten Island CUNY        │ Staten Island  │ NY      │  40.60183 │  -74.14849 │ www.csi.cuny.edu/              │      15440.00 │   NULL │      0.13332635 │ 2288    │ College of Staten Island          │ NULL          │    0.0 │        0.0 │       0.0 │ NCAA - Division III │ [40.5795317, -74.1502007]               │ Staten Island  │ NY        │ NULL                                                │           4 │     NULL │          1 │
# │     180984 │ Concordia University-Nebraska        │ Seward         │ NE      │ 40.914852 │  -97.08905 │ www.cune.edu/                  │      39330.00 │   NULL │      0.13487434 │ 1878    │ Concordia University, Nebraska    │ NULL          │  51.13 │      10.46 │      7.51 │ NAIA                │ [41.4925374, -99.9018131]               │ NULL           │ NE        │ NULL                                                │          23 │     NULL │          1 │
# │        ·   │             ·                        │   ·            │ ·       │      ·    │      ·     │      ·                         │          ·    │     ·  │           ·     │  ·      │             ·                     │  ·            │    ·   │         ·  │        ·  │  ·                  │             ·                           │  ·             │ ·         │  ·                                                  │           · │       ·  │          · │
# │        ·   │             ·                        │   ·            │ ·       │      ·    │      ·     │      ·                         │          ·    │     ·  │           ·     │  ·      │             ·                     │  ·            │    ·   │         ·  │        ·  │  ·                  │             ·                           │  ·             │ ·         │  ·                                                  │           · │       ·  │          · │
# │        ·   │             ·                        │   ·            │ ·       │      ·    │      ·     │      ·                         │          ·    │     ·  │           ·     │  ·      │             ·                     │  ·            │    ·   │         ·  │        ·  │  ·                  │             ·                           │  ·             │ ·         │  ·                                                  │           · │       ·  │          · │
# │     234155 │ Virginia State University            │ Petersburg     │ VA      │  37.23469 │  -77.41903 │ www.vsu.edu/                   │      22006.00 │   NULL │      0.13737524 │ 1551    │ Virginia State University         │ NULL          │  46.59 │       9.17 │      6.33 │ NCAA - Division II  │ [37.4315734, -78.6568942]               │ NULL           │ VA        │ http://govsutrojans.com/                            │          15 │     NULL │          1 │
# │     152673 │ Wabash College                       │ Crawfordsville │ IN      │ 40.037586 │    -86.906 │ www.wabash.edu/                │      49125.00 │   NULL │      0.14561093 │ 1812    │ Wabash College                    │ NULL          │  54.95 │       9.51 │      8.76 │ NCAA - Division III │ [40.0411536, -86.87445160000001]        │ Crawfordsville │ IN        │ https://sports.wabash.edu/sports/tennis             │          31 │     NULL │          1 │
# │     234207 │ Washington and Lee University        │ Lexington      │ VA      │  37.78894 │ -79.443016 │ www.wlu.edu/                   │      64525.00 │   NULL │      0.12851799 │ 1654    │ Washington & Lee University       │ NULL          │  62.41 │       11.1 │     10.05 │ NCAA - Division III │ [37.78402080000001, -79.4428157]        │ Lexington      │ VA        │ http://generalssports.com/sports/mten/index         │          91 │     NULL │          1 │
# │     168227 │ Wentworth Institute of Technology    │ Boston         │ MA      │  42.33663 │ -71.094986 │ https://wit.edu/               │      41010.00 │   NULL │       0.1329943 │ 2295    │ Wentworth Institute of Technology │ NULL          │  42.43 │       8.23 │      6.37 │ NCAA - Division III │ [42.3600825, -71.0588801]               │ Boston         │ MA        │ NULL                                                │           9 │     NULL │          1 │
# │     130776 │ Western Connecticut State University │ Danbury        │ CT      │ 41.400364 │  -73.44427 │ https://www.wcsu.edu/          │      16095.00 │   NULL │       0.1423316 │ 2279    │ Western Connecticut State         │ NULL          │  33.73 │       7.19 │      4.04 │ NCAA - Division III │ [41.394817, -73.4540111]                │ Danbury        │ CT        │ NULL                                                │           4 │     NULL │          1 │
# │     156125 │ Wichita State University             │ Wichita        │ KS      │ 37.718884 │  -97.29236 │ www.wichita.edu/               │      19240.00 │   NULL │       0.1345517 │ 1007    │ Wichita State University          │ Wichita State │  72.79 │      12.43 │     11.69 │ NCAA - Division I   │ [37.68717609999999, -97.33005299999999] │ Wichita        │ KS        │ https://goshockers.com/index.aspx?path=mten         │         154 │     NULL │          1 │
# │     179964 │ William Woods University             │ Fulton         │ MO      │ 38.860287 │  -91.95042 │ https://www.williamwoods.edu/  │      28860.00 │   NULL │      0.12685555 │ 3004    │ William Woods University          │ NULL          │  60.98 │      10.89 │      9.44 │ NAIA                │ [38.84670819999999, -91.94795859999999] │ Fulton         │ MO        │ https://wwuowls.com/sports/mens-tennis              │          51 │     NULL │          1 │
# │     240338 │ Wisconsin Lutheran College           │ Milwaukee      │ WI      │  43.03694 │  -88.02272 │ www.wlc.edu/                   │      35080.00 │   NULL │      0.12617403 │ 2135    │ Wisconsin Lutheran College        │ NULL          │  38.13 │       7.66 │      5.17 │ NCAA - Division III │ [43.0389025, -87.9064736]               │ Milwaukee      │ WI        │ https://www.wlcsports.com/sports/mten/index         │           9 │     NULL │          1 │
# │     190691 │ CUNY York College                    │ Jamaica        │ NY      │ 40.701576 │  -73.79631 │ www.york.cuny.edu/             │      15308.00 │   NULL │      0.12671953 │ 2726    │ York College (New York)           │ NULL          │  18.22 │       3.87 │       1.9 │ NCAA - Division III │ [40.7037439, -73.7991953]               │ Queens         │ NY        │ NULL                                                │           5 │     NULL │          1 │
# │     217059 │ York College of Pennsylvania         │ York           │ PA      │  39.94614 │  -76.72798 │ https://www.ycp.edu/           │      24606.00 │   NULL │       0.1383968 │ 2603    │ York College (Pennsylvania)       │ NULL          │  37.67 │       7.16 │      4.78 │ NCAA - Division III │ [39.9625984, -76.727745]                │ York           │ PA        │ NULL                                                │           7 │     NULL │          1 │
# ├────────────┴──────────────────────────────────────┴────────────────┴─────────┴───────────┴────────────┴────────────────────────────────┴───────────────┴────────┴─────────────────┴─────────┴───────────────────────────────────┴───────────────┴────────┴────────────┴───────────┴─────────────────────┴─────────────────────────────────────────┴────────────────┴───────────┴─────────────────────────────────────────────────────┴─────────────┴──────────┴────────────┤
# │ 80 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                              24 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%quack
#
# DROP TABLE IF EXISTS utr_cosine_matches;
# CREATE TABLE utr_cosine_matches as
# SELECT
#     utr_vec.* exclude (vectors),
#     array_cosine_distance(utr_vec.vectors, costs_vec.vectors)::float as cosine_distance,
#     costs_vec.college_id as other_college_id
# FROM utr_vec
# LEFT JOIN costs_vec ON utr_vec.stateAbbr = costs_vec.state  -- at least match on state
# WHERE array_cosine_distance(utr_vec.vectors, costs_vec.vectors) < 0.5
# ;

# %%
# %%quack
#
# DROP TABLE IF EXISTS utr_best_matches;
# CREATE TABLE utr_best_matches as
# SELECT DISTINCT ON (id)
#     *
# FROM utr_cosine_matches
# ORDER BY id, cosine_distance
# ;

# %%
# %%quack
# -- │   id    │                  name                  │       shortName       │ power6 │ power6High │ power6Low │    divisionName     │              latLng               │   cityName   │ stateAbbr │                                                url                                                 │ memberCount │ cosine_distance │ other_college_id │ college_id │                    college_name                     │                         short_name                         │                      join_name                      │     city     │  state  │ latitude  │ longitude  │              url              │  total_cost   │
#
# select
#     id,
#     concat(name, '[ ', shortName, ' ]') as utr_name,
#     concat(college_name, '[ ', short_name, ' ]') as ipeds_name,
#     cityName,
#     city,
#     college_id,
#     cosine_distance,
# from utr_best_matches
# LEFT join costs_vec on utr_best_matches.other_college_id = costs_vec.college_id
# ;
# Out:
# ┌─────────┬────────────────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────┬──────────────┬────────────┬─────────────────┐
# │   id    │                                      utr_name                                      │                                                    ipeds_name                                                     │   cityName   │     city     │ college_id │ cosine_distance │
# │ varchar │                                      varchar                                       │                                                      varchar                                                      │   varchar    │   varchar    │   int64    │      float      │
# ├─────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────┼──────────────┼────────────┼─────────────────┤
# │ 1473    │ Alabama A&M University[ Alabama A&M ]                                              │ Alabama A & M University[ AAMU ]                                                                                  │ Huntsville   │ Normal       │     100654 │      0.14485985 │
# │ 1558    │ Auburn University Montgomery[  ]                                                   │ Auburn University at Montgomery[ AUM||Auburn University at Montgomery|Auburn Montgomery ]                         │ Montgomery   │ Montgomery   │     100830 │       0.0840978 │
# │ 943     │ Auburn University[ Auburn ]                                                        │ Auburn University[  ]                                                                                             │ Auburn       │ Auburn       │     100858 │      0.19287753 │
# │ 1491    │ Gadsden State Community College[  ]                                                │ Gadsden State Community College[ GSCC | Gadsden State | Gadsden Community College ]                               │ Gadsden      │ Gadsden      │     101240 │     0.061249733 │
# │ 3047    │ Wallace State Comm. College-Hanceville[  ]                                         │ George C Wallace State Community College-Hanceville[ Wallace State Community College Wallace State - Hanceville ] │ Hanceville   │ Hanceville   │     101295 │      0.08707738 │
# │ 2546    │ Huntingdon College (Ala.)[  ]                                                      │ Huntingdon College[  ]                                                                                            │ Montgomery   │ Montgomery   │     101435 │      0.05009836 │
# │ 2440    │ Marion Military Institute[  ]                                                      │ Marion Military Institute[  ]                                                                                     │ Marion       │ Marion       │     101648 │     0.051241934 │
# │ 2752    │ University of Mobile (Ala.)[  ]                                                    │ University of Mobile[ University of Mobile ]                                                                      │ Mobile       │ Mobile       │     101693 │      0.08257496 │
# │ 2099    │ University of Montevallo[  ]                                                       │ University of Montevallo[  ]                                                                                      │ Montevallo   │ Montevallo   │     101709 │      0.20423114 │
# │ 1280    │ University of South Alabama[ South Alabama ]                                       │ University of South Alabama[  ]                                                                                   │ Mobile       │ Mobile       │     102094 │      0.03450972 │
# │  ·      │                      ·                                                             │                ·                                                                                                  │   ·          │   ·          │        ·   │           ·     │
# │  ·      │                      ·                                                             │                ·                                                                                                  │   ·          │   ·          │        ·   │           ·     │
# │  ·      │                      ·                                                             │                ·                                                                                                  │   ·          │   ·          │        ·   │           ·     │
# │ 1279627 │ Lewis & Clark Community College[ Lewis & Clark Community College ]                 │ Lewis and Clark Community College[  ]                                                                             │ Godfrey      │ Godfrey      │     146603 │     0.036892533 │
# │ 1443    │ Georgetown College[  ]                                                             │ Georgetown College[  ]                                                                                            │ Georgetown   │ Georgetown   │     156745 │     0.046819508 │
# │ 1878    │ Concordia University, Nebraska[  ]                                                 │ Concordia University-Nebraska[ Concordia Teachers College  Concordia College  Concordia University, Seward ]      │ NULL         │ Seward       │     180984 │      0.13487434 │
# │ 1366023 │ Coastal Alabama Community College North[ Coastal Alabama Community College North ] │ Coastal Alabama Community College[  ]                                                                             │ Monroeville  │ Bay Minette  │     101161 │      0.19086242 │
# │ 1855    │ Edinboro University[  ]                                                            │ Wilkes University[ Wilkes ]                                                                                       │ Edinboro     │ Wilkes-Barre │     216931 │       0.2972737 │
# │ 1098923 │ University of Tennessee Southern[ UT Southern ]                                    │ The University of Tennessee Southern[  ]                                                                          │ Pulaski      │ Pulaski      │     220701 │     0.041730225 │
# │ 2372    │ Castleton State College[  ]                                                        │ Champlain College[  ]                                                                                             │ Castleton    │ Burlington   │     230852 │      0.25919777 │
# │ 2803    │ Vermont State University Lyndon[ VTSU Lyndon ]                                     │ Vermont State University[  ]                                                                                      │ Lyndon       │ Randolph     │     231165 │     0.121783674 │
# │ 1151    │ University of Pennsylvania[ Penn ]                                                 │ Drexel University[ Drexel ]                                                                                       │ Philadelphia │ Philadelphia │     212054 │      0.26736313 │
# │ 2383    │ Johnson State College[  ]                                                          │ Vermont State University[  ]                                                                                      │ East Johnson │ Randolph     │     231165 │      0.24588501 │
# ├─────────┴────────────────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────┴──────────────┴────────────┴─────────────────┤
# │ 948 rows (20 shown)                                                                                                                                                                                                                                                 7 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
utr_costs = conn.sql(r"""
SELECT
    utr.*,
    costs.college_id,
    costs.total_cost
FROM utr
LEFT JOIN costs ON (
    (
        regexp_replace(utr.name, '\W', '', 'g') IN (regexp_replace(costs.join_name, '\W', '', 'g'))
        OR 
        (
            LENGTH(utr.shortName) > 1
            AND LENGTH(costs.short_name) > 1      
            AND regexp_replace(utr.shortName, '\W', '', 'g') IN ( regexp_replace(costs.short_name, '\W', '', 'g'))
        )
    )
    OR
    (
        concat(regexp_replace(utr.name, '\W', '', 'g'), cityName) IN (regexp_replace(costs.join_name, '\W', '', 'g'))
    )
    OR
    (
        LENGTH(utr.shortName) > 1
        AND list_has_any(regexp_split_to_array(short_name, '\s*\|\s*'), [utr.shortName, utr.name, utr.shortName || ' ' || utr.cityName])
    )
    )                     
    AND utr.stateAbbr = costs.state                     
""")

conn.sql("""\
SELECT
    utr.*,
FROM utr_costs AS utr
WHERE utr.college_id IS NULL
""")

# %%
# %%quack
#
# SELECT
#     *
# FROM costs WHERE college_name ilike '%Arizona%University%';
# Out:
# ┌────────────┬────────────────────────────────────────────┬─────────────┬────────────────────────────────────────────┬────────────┬─────────┬───────────┬─────────────┬───────────────┐
# │ college_id │                college_name                │ short_name  │                 join_name                  │    city    │  state  │ latitude  │  longitude  │  total_cost   │
# │   int64    │                  varchar                   │   varchar   │                  varchar                   │  varchar   │ varchar │   float   │    float    │ decimal(10,2) │
# ├────────────┼────────────────────────────────────────────┼─────────────┼────────────────────────────────────────────┼────────────┼─────────┼───────────┼─────────────┼───────────────┤
# │     104151 │ Arizona State University Campus Immersion  │ ASU Tempe   │ Arizona State University Campus Immersion  │ Tempe      │ AZ      │  33.41772 │  -111.93438 │      32193.00 │
# │     105330 │ Northern Arizona University                │ NAU         │ Northern Arizona University                │ Flagstaff  │ AZ      │  35.18845 │ -111.653725 │      28900.00 │
# │     105899 │ Arizona Christian University               │             │ Arizona Christian University               │ Glendale   │ AZ      │  33.62295 │  -112.18178 │      34697.00 │
# │     483124 │ Arizona State University Digital Immersion │ ASU Skysong │ Arizona State University Digital Immersion │ Scottsdale │ AZ      │ 33.463516 │ -111.924484 │          NULL │
# └────────────┴────────────────────────────────────────────┴─────────────┴────────────────────────────────────────────┴────────────┴─────────┴───────────┴─────────────┴───────────────┘

# %%
# %%quack
#
# WITH unmatched_costs AS (
#   SELECT
#     costs.*,
#   FROM costs
#   LEFT JOIN utr_costs ON costs.college_id = utr_costs.college_id
#   WHERE utr_costs.college_id is null
# )
# SELECT
#   utr.*,
#   costs.college_name,
#   costs.short_name,
#   costs.college_id,
#   costs.total_cost,
#   round(ST_Distance(ST_Point(utr.latLng[1], utr.latLng[2]), ST_Point(costs.latitude, costs.longitude)), 3) as dist
# FROM utr_costs AS utr
# LEFT JOIN unmatched_costs AS costs ON ST_Distance(ST_Point(utr.latLng[1], utr.latLng[2]), ST_Point(costs.latitude, costs.longitude)) < 0.02
# WHERE name ilike '%Arizona%University%'
#   AND utr.college_id is null
# ORDER BY name, dist
# ;
# Out:
# ┌─────────┬──────────────────────────┬───────────────┬────────┬────────────┬───────────┬───────────────────┬────────────────────────────┬──────────┬───────────┬──────────────────────────────────────────────────┬─────────────┬────────────┬───────────────┬───────────────────────────────────────────┬──────────────────┬────────────┬───────────────┬────────┐
# │   id    │           name           │   shortName   │ power6 │ power6High │ power6Low │   divisionName    │           latLng           │ cityName │ stateAbbr │                       url                        │ memberCount │ college_id │  total_cost   │               college_name                │    short_name    │ college_id │  total_cost   │  dist  │
# │ varchar │         varchar          │    varchar    │ double │   double   │  double   │      varchar      │          double[]          │ varchar  │  varchar  │                     varchar                      │    int64    │   int64    │ decimal(10,2) │                  varchar                  │     varchar      │   int64    │ decimal(10,2) │ double │
# ├─────────┼──────────────────────────┼───────────────┼────────┼────────────┼───────────┼───────────────────┼────────────────────────────┼──────────┼───────────┼──────────────────────────────────────────────────┼─────────────┼────────────┼───────────────┼───────────────────────────────────────────┼──────────────────┼────────────┼───────────────┼────────┤
# │ 1700    │ Arizona State University │ Arizona State │   78.2 │      13.99 │     12.35 │ NCAA - Division I │ [33.4255104, -111.9400054] │ Tempe    │ AZ        │ http://www.thesundevils.com/index.aspx?path=mten │         110 │       NULL │          NULL │ Sessions College for Professional Design  │ Sessions College │     475839 │      12440.00 │  0.002 │
# │ 1700    │ Arizona State University │ Arizona State │   78.2 │      13.99 │     12.35 │ NCAA - Division I │ [33.4255104, -111.9400054] │ Tempe    │ AZ        │ http://www.thesundevils.com/index.aspx?path=mten │         110 │       NULL │          NULL │ Arizona State University Campus Immersion │ ASU Tempe        │     104151 │      32193.00 │   0.01 │
# │ 1700    │ Arizona State University │ Arizona State │   78.2 │      13.99 │     12.35 │ NCAA - Division I │ [33.4255104, -111.9400054] │ Tempe    │ AZ        │ http://www.thesundevils.com/index.aspx?path=mten │         110 │       NULL │          NULL │ Bryan University                          │                  │     110219 │      12185.00 │  0.013 │
# └─────────┴──────────────────────────┴───────────────┴────────┴────────────┴───────────┴───────────────────┴────────────────────────────┴──────────┴───────────┴──────────────────────────────────────────────────┴─────────────┴────────────┴───────────────┴───────────────────────────────────────────┴──────────────────┴────────────┴───────────────┴────────┘
