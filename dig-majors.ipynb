# %%
import duckdb
import pandas as pd

conn = duckdb.connect('data/duck.db')

conn.sql("""\
INSTALL spatial;
LOAD spatial;
         
INSTALL vss;
LOAD vss;
         
SET hnsw_enable_experimental_persistence = true;
""")


from IPython.core.magic import (register_line_magic, register_cell_magic, register_line_cell_magic, needs_local_scope)
from IPython.core.magic_arguments import (argument, magic_arguments, parse_argstring)

@magic_arguments()
@argument('query', nargs='*', help="The SQL query to execute")
@argument('--db', '-d', default=None, help="Which connection to use")
@argument('--output', '-o', default=None, help="Name of the variable to store output DataFrame in local scope")
@register_line_cell_magic
@needs_local_scope
def quack(line, cell=None, local_ns=None):
    "Magic that works both as %lcmagic and as %%lcmagic"

    args = parse_argstring(quack, line)
    query = cell if cell else ' '.join(args.query)

    if args.db:
        conn = local_ns[args.db]
    elif 'conn' in local_ns:
        conn = local_ns['conn']
    else:
        
        conn = duckdb.connect(':memory:')
        local_ns['conn'] = conn

    result = conn.sql(query)
    
    if args.output:
        local_ns[args.output] = result
    return result

programs = pd.read_csv('data/c2023_a.csv', encoding='latin1')
programs = programs[programs['CIPCODE'] != 99]  # 99 = Grand Total
cip_codes = pd.read_csv('data/cip_codes.csv')

# %%
# %%quack
#
# SELECT
#     cipcode,
#     cip_codes.cip_name,
#     sum(CTOTALT) as total_graduates,
#     count(1)
# FROM programs
# LEFT JOIN cip_codes ON programs.CIPCODE = cip_codes.cip_id
# WHERE UNITID = 101709
# GROUP BY 1, 2
# ORDER BY 3 DESC
# Out:
# ┌─────────┬──────────────────────────────────────────────────────────────┬─────────────────┬──────────┐
# │ CIPCODE │                           cip_name                           │ total_graduates │ count(1) │
# │ double  │                           varchar                            │     int128      │  int64   │
# ├─────────┼──────────────────────────────────────────────────────────────┼─────────────────┼──────────┤
# │ 52.0201 │ Business Administration and Management, General              │              70 │        3 │
# │ 13.1202 │ Elementary Education and Teaching                            │              46 │        2 │
# │ 31.0505 │ Exercise Science and Kinesiology                             │              46 │        2 │
# │ 50.0701 │ Art/Art Studies, General                                     │              38 │        1 │
# │ 13.1101 │ Counselor Education/School Counseling and Guidance Services  │              38 │        1 │
# │ 52.1401 │ Marketing/Marketing Management, General                      │              34 │        2 │
# │ 51.0203 │ Speech-Language Pathology/Pathologist                        │              33 │        2 │
# │ 13.1205 │ Secondary Education and Teaching                             │              24 │        2 │
# │ 50.0501 │ Drama and Dramatics/Theatre Arts, General                    │              23 │        1 │
# │ 42.0101 │ Psychology, General                                          │              21 │        2 │
# │    ·    │      ·                                                       │               · │        · │
# │    ·    │      ·                                                       │               · │        · │
# │    ·    │      ·                                                       │               · │        · │
# │ 11.0104 │ Informatics                                                  │               7 │        1 │
# │ 51.0202 │ Audiology/Audiologist                                        │               7 │        1 │
# │ 52.1301 │ Management Science                                           │               5 │        1 │
# │ 13.0101 │ Education, General                                           │               5 │        1 │
# │ 40.0501 │ Chemistry, General                                           │               4 │        1 │
# │ 45.0101 │ Social Sciences, General                                     │               3 │        1 │
# │ 16.0101 │ Foreign Languages and Literatures, General                   │               2 │        2 │
# │ 11.0701 │ Computer Science                                             │               1 │        1 │
# │ 30.9999 │ Multi-/Interdisciplinary Studies, Other                      │               0 │        1 │
# │ 31.0501 │ Sports, Kinesiology, and Physical Education/Fitness, General │               0 │        1 │
# ├─────────┴──────────────────────────────────────────────────────────────┴─────────────────┴──────────┤
# │ 36 rows (20 shown)                                                                        4 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%quack --output program_mens
#
# DROP TABLE IF EXISTS program_mens;
# CREATE TABLE program_mens AS
# WITH raw AS (
#   SELECT
#       UNITID,
#       cipcode,
#       cip_name,
#       ctotalm,
#       ctotalm / sum(CTOTALM) OVER (PARTITION BY UNITID) as pct_awards,
#   FROM programs
#   JOIN cip_codes ON programs.CIPCODE = cip_codes.cip_id
#   WHERE CTOTALM > 0
#   ORDER BY 3 DESC
# )
# SELECT
#   unitid,
#   cipcode,
#   cip_name,
#   SUM(pct_awards) as pct_awards,
#   SUM(ctotalm) as total_awards,
# FROM raw
# WHERE pct_awards IS NOT NULL
# GROUP BY 1, 2, 3
# ORDER BY pct_awards DESC;
#
# SELECT * FROM program_mens;
# Out:
# ┌────────┬─────────┬───────────────────────────────────────────────────────────────────────┬─────────────────────┬──────────────┐
# │ UNITID │ CIPCODE │                               cip_name                                │     pct_awards      │ total_awards │
# │ int64  │ double  │                                varchar                                │       double        │    int128    │
# ├────────┼─────────┼───────────────────────────────────────────────────────────────────────┼─────────────────────┼──────────────┤
# │ 494603 │  5.0122 │ Regional Studies (U.S., Canadian, Foreign)                            │  1.0000000000000002 │          490 │
# │ 213589 │ 47.0604 │ Automobile/Automotive Mechanics Technology/Technician                 │                 1.0 │          132 │
# │ 448257 │ 12.0409 │ Aesthetician/Esthetician and Skin Care Specialist                     │                 1.0 │            1 │
# │ 455062 │ 12.0409 │ Aesthetician/Esthetician and Skin Care Specialist                     │                 1.0 │            1 │
# │ 151607 │ 12.0409 │ Aesthetician/Esthetician and Skin Care Specialist                     │                 1.0 │            1 │
# │ 487995 │ 51.3301 │ Acupuncture and Oriental Medicine                                     │                 1.0 │           10 │
# │ 122117 │ 51.3301 │ Acupuncture and Oriental Medicine                                     │                 1.0 │           12 │
# │ 449481 │ 51.3301 │ Acupuncture and Oriental Medicine                                     │                 1.0 │            2 │
# │ 439914 │ 51.3301 │ Acupuncture and Oriental Medicine                                     │                 1.0 │            2 │
# │ 384306 │ 51.3301 │ Acupuncture and Oriental Medicine                                     │                 1.0 │            8 │
# │    ·   │    ·    │             ·                                                         │                  ·  │            · │
# │    ·   │    ·    │             ·                                                         │                  ·  │            · │
# │    ·   │    ·    │             ·                                                         │                  ·  │            · │
# │ 199731 │ 48.0508 │ Welding Technology/Welder                                             │ 0.11151079136690648 │           31 │
# │ 215770 │ 52.1301 │ Management Science                                                    │  0.1114727420667209 │          137 │
# │ 189088 │ 50.0702 │ Fine/Studio Arts, General                                             │ 0.11145510835913312 │           36 │
# │ 218742 │ 51.3801 │ Registered Nursing/Registered Nurse                                   │ 0.11142857142857143 │           39 │
# │ 173708 │ 15.1103 │ Hydraulics and Fluid Power Technology/Technician                      │  0.1113967437874893 │          130 │
# │ 219833 │ 52.0201 │ Business Administration and Management, General                       │ 0.11138014527845036 │           46 │
# │ 222576 │ 15.0403 │ Electromechanical/Electromechanical Engineering Technology/Technician │ 0.11133603238866396 │          110 │
# │ 171146 │ 52.0201 │ Business Administration and Management, General                       │         0.111328125 │           57 │
# │ 222992 │ 11.0201 │ Computer Programming/Programmer, General                              │ 0.11132749107432652 │          343 │
# │ 159939 │ 52.0201 │ Business Administration and Management, General                       │ 0.11129032258064517 │           69 │
# ├────────┴─────────┴───────────────────────────────────────────────────────────────────────┴─────────────────────┴──────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                       5 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
program_mens = program_mens.to_df()

# %%
# %%quack
#
# WITH raw AS (
#   SELECT
#       UNITID,
#       cipcode,
#       cip_codes.cip_name,
#       ctotalm,
#       ctotalm / sum(CTOTALM) OVER (PARTITION BY UNITID) as pct_graduates,
#   FROM program_mens
#   LEFT JOIN cip_codes ON program_mens.CIPCODE = cip_codes.cip_id
#   WHERE UNITID = 145813
#   ORDER BY 3 DESC
# ), percentages AS (
#   SELECT
#     unitid,
#     cipcode,
#     cip_name,
#     SUM(ctotalm) as total_graduates,
#     SUM(pct_graduates) as pct_graduates
#   FROM raw
#   GROUP BY 1, 2, 3
#   ORDER BY pct_graduates DESC
# ), ranks AS (
# SELECT
#   *,
#   SUM(pct_graduates) OVER (ORDER BY pct_graduates DESC) as cumulative_pct,
#   ROW_NUMBER() OVER (ORDER BY pct_graduates DESC) as rank
# FROM percentages
# )
# SELECT
#   *
# FROM ranks
# WHERE cumulative_pct <= 0.5
# Out:
# ┌────────┬─────────┬──────────────────────────────────────────────────────────────────────────┬─────────────────┬──────────────────────┬─────────────────────┬───────┐
# │ UNITID │ CIPCODE │                                 cip_name                                 │ total_graduates │    pct_graduates     │   cumulative_pct    │ rank  │
# │ int64  │ double  │                                 varchar                                  │     int128      │        double        │       double        │ int64 │
# ├────────┼─────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────┼──────────────────────┼─────────────────────┼───────┤
# │ 145813 │ 52.0201 │ Business Administration and Management, General                          │             150 │  0.06521739130434782 │ 0.06521739130434782 │     1 │
# │ 145813 │ 52.0801 │ Finance, General                                                         │             141 │  0.06130434782608696 │  0.1265217391304348 │     2 │
# │ 145813 │ 52.1401 │ Marketing/Marketing Management, General                                  │             130 │  0.05652173913043478 │ 0.18304347826086959 │     3 │
# │ 145813 │ 52.0301 │ Accounting                                                               │             118 │  0.05130434782608696 │ 0.23434782608695653 │     4 │
# │ 145813 │ 43.0104 │ Criminal Justice/Safety Studies                                          │              74 │  0.03217391304347826 │  0.2665217391304348 │     5 │
# │ 145813 │ 11.0701 │ Computer Science                                                         │              71 │ 0.030869565217391304 │  0.2973913043478261 │     6 │
# │ 145813 │ 54.0101 │ History, General                                                         │              69 │                 0.03 │ 0.32739130434782615 │     7 │
# │ 145813 │ 11.1003 │ Computer and Information Systems Security/Auditing/Information Assurance │              66 │ 0.028695652173913042 │  0.3847826086956523 │     8 │
# │ 145813 │     1.0 │ Agriculture, General                                                     │              66 │ 0.028695652173913042 │  0.3847826086956523 │     9 │
# │ 145813 │ 52.1301 │ Management Science                                                       │              63 │  0.02739130434782609 │  0.4121739130434784 │    10 │
# │ 145813 │ 27.0101 │ Mathematics, General                                                     │              53 │ 0.023043478260869568 │ 0.43521739130434794 │    11 │
# ├────────┴─────────┴──────────────────────────────────────────────────────────────────────────┴─────────────────┴──────────────────────┴─────────────────────┴───────┤
# │ 11 rows                                                                                                                                                  7 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%quack
#
# WITH raw AS (
#   SELECT
#       UNITID,
#       cipcode,
#       cip_codes.cip_name,
#       ctotalm,
#       ctotalm / sum(CTOTALM) OVER (PARTITION BY UNITID) as pct_graduates,
#   FROM program_mens
#   LEFT JOIN cip_codes ON program_mens.CIPCODE = cip_codes.cip_id
#   WHERE UNITID = 145813
#   ORDER BY 3 DESC
# ), percentages AS (
#   SELECT
#     unitid,
#     cipcode,
#     cip_name,
#     SUM(ctotalm) as total_graduates,
#     SUM(pct_graduates) as pct_graduates
#   FROM raw
#   GROUP BY 1, 2, 3
#   ORDER BY pct_graduates DESC
# ), ranks AS (
# SELECT
#   *,
#   SUM(pct_graduates) OVER (ORDER BY pct_graduates DESC) as cumulative_pct,
#   ROW_NUMBER() OVER (ORDER BY pct_graduates DESC) as rank
# FROM percentages
# )
# PIVOT ranks
# ON 'cip_rank_' || rank IN ('cip_rank_1', 'cip_rank_2', 'cip_rank_3', 'cip_rank_4', 'cip_rank_5')
# USING min(cipcode)
# GROUP BY unitid
# Out:
# ┌────────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ UNITID │ cip_rank_1 │ cip_rank_2 │ cip_rank_3 │ cip_rank_4 │ cip_rank_5 │
# │ int64  │   double   │   double   │   double   │   double   │   double   │
# ├────────┼────────────┼────────────┼────────────┼────────────┼────────────┤
# │ 145813 │    52.0201 │    52.0801 │    52.1401 │    52.0301 │    43.0104 │
# └────────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
# %%quack --output majors
#
# WITH raw AS (
#   SELECT
#       UNITID,
#       cipcode,
#       cip_codes.cip_name,
#       total_awards,
#       total_awards / sum(total_awards) OVER (PARTITION BY UNITID) as pct_awards,
#   FROM program_mens
#   LEFT JOIN cip_codes ON program_mens.CIPCODE = cip_codes.cip_id
#   --WHERE UNITID = 145813
#   ORDER BY 1, 5 DESC
# ), percentages AS (
#   SELECT
#     unitid,
#     cipcode,
#     cip_name,
#     SUM(total_awards) as total_graduates,
#     SUM(pct_awards) as pct_awards
#   FROM raw
#   GROUP BY 1, 2, 3
#   ORDER BY pct_awards DESC
# ), ranks AS (
# SELECT
#   *,
#   SUM(pct_awards) OVER (PARTITION BY unitid ORDER BY pct_awards DESC) as cumulative_pct,
#   ROW_NUMBER() OVER (PARTITION BY unitid ORDER BY pct_awards DESC) as rank
# FROM percentages
# )
# SELECT
#     unitid as college_id,
#     array_agg(
#         {
#             rank: rank,
#             cipcode: cipcode,
#             cip_name: cip_name,
#             total_graduates: total_graduates,
#             pct_awards: round(pct_awards, 2),
#         }
#     ) as top_cips
# FROM ranks
# WHERE cumulative_pct <= .5
# GROUP BY unitid
# Out:
# ┌────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ college_id │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             top_cips                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │   int64    │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               struct(rank bigint, cipcode double, cip_name varchar, total_graduates hugeint, pct_awards double)[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │
# ├────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │     196219 │ [{'rank': 1, 'cipcode': 9.01, 'cip_name': Communication, General, 'total_graduates': 21, 'pct_awards': 0.07}, {'rank': 2, 'cipcode': 50.0504, 'cip_name': Playwriting and Screenwriting, 'total_graduates': 20, 'pct_awards': 0.06}, {'rank': 3, 'cipcode': 50.0509, 'cip_name': Musical Theatre, 'total_graduates': 18, 'pct_awards': 0.06}, {'rank': 4, 'cipcode': 42.0101, 'cip_name': Psychology, General, 'total_graduates': 16, 'pct_awards': 0.05}, {'rank': 5, 'cipcode': 50.1002, 'cip_name': Fine and Studio Arts Management, 'total_graduates': 15, 'pct_awards': 0.05}, {'rank': 6, 'cipcode': 27.0101, 'cip_name': Mathematics, General, 'total_graduates': 13, 'pct_awards': 0.04}, {'rank': 7, 'cipcode': 50.0901, 'cip_name': Music, General, 'total_graduates': 13, 'pct_awards': 0.04}, {'rank': 8, 'cipcode': 9.0702, 'cip_name': Digital Communication and Media/Multimedia, 'total_graduates': 13, 'pct_awards': 0.04}]                                                                                                                                                                                                                                                                                                                                                                                     │
# │     198534 │ [{'rank': 1, 'cipcode': 24.0199, 'cip_name': Liberal Arts and Sciences, General Studies and Humanities, Other, 'total_graduates': 155, 'pct_awards': 0.16}, {'rank': 2, 'cipcode': 11.0103, 'cip_name': Information Technology, 'total_graduates': 115, 'pct_awards': 0.12}, {'rank': 3, 'cipcode': 24.0101, 'cip_name': Liberal Arts and Sciences/Liberal Studies, 'total_graduates': 104, 'pct_awards': 0.11}, {'rank': 4, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 67, 'pct_awards': 0.07}, {'rank': 5, 'cipcode': 47.0604, 'cip_name': Automobile/Automotive Mechanics Technology/Technician, 'total_graduates': 48, 'pct_awards': 0.05}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# │     200341 │ [{'rank': 1, 'cipcode': 24.0101, 'cip_name': Liberal Arts and Sciences/Liberal Studies, 'total_graduates': 36, 'pct_awards': 0.3}, {'rank': 2, 'cipcode': 47.0613, 'cip_name': Medium/Heavy Vehicle and Truck Technology/Technician, 'total_graduates': 24, 'pct_awards': 0.2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │
# │     218964 │ [{'rank': 1, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 111, 'pct_awards': 0.32}, {'rank': 2, 'cipcode': 26.0101, 'cip_name': Biology/Biological Sciences, General, 'total_graduates': 17, 'pct_awards': 0.05}, {'rank': 3, 'cipcode': 31.0504, 'cip_name': Sport and Fitness Administration/Management, 'total_graduates': 17, 'pct_awards': 0.05}, {'rank': 4, 'cipcode': 31.0505, 'cip_name': Exercise Science and Kinesiology, 'total_graduates': 13, 'pct_awards': 0.04}, {'rank': 5, 'cipcode': 42.0101, 'cip_name': Psychology, General, 'total_graduates': 12, 'pct_awards': 0.03}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │     228501 │ [{'rank': 1, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 20, 'pct_awards': 0.11}, {'rank': 2, 'cipcode': 43.0104, 'cip_name': Criminal Justice/Safety Studies, 'total_graduates': 19, 'pct_awards': 0.1}, {'rank': 3, 'cipcode': 31.0505, 'cip_name': Exercise Science and Kinesiology, 'total_graduates': 18, 'pct_awards': 0.1}, {'rank': 4, 'cipcode': 3.0201, 'cip_name': Environmental/Natural Resources Management and Policy, General, 'total_graduates': 14, 'pct_awards': 0.08}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │
# │     229780 │ [{'rank': 1, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 156, 'pct_awards': 0.35}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │
# │     240480 │ [{'rank': 1, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 81, 'pct_awards': 0.11}, {'rank': 2, 'cipcode': 3.0601, 'cip_name': Wildlife, Fish and Wildlands Science and Management, 'total_graduates': 42, 'pct_awards': 0.06}, {'rank': 3, 'cipcode': 3.0501, 'cip_name': Forestry, General, 'total_graduates': 41, 'pct_awards': 0.06}, {'rank': 4, 'cipcode': 3.0201, 'cip_name': Environmental/Natural Resources Management and Policy, General, 'total_graduates': 41, 'pct_awards': 0.06}, {'rank': 5, 'cipcode': 3.0301, 'cip_name': Fishing and Fisheries Sciences and Management, 'total_graduates': 28, 'pct_awards': 0.04}, {'rank': 6, 'cipcode': 24.0199, 'cip_name': Liberal Arts and Sciences, General Studies and Humanities, Other, 'total_graduates': 28, 'pct_awards': 0.04}, {'rank': 7, 'cipcode': 52.0801, 'cip_name': Finance, General, 'total_graduates': 23, 'pct_awards': 0.03}, {'rank': 8, 'cipcode': 26.0101, 'cip_name': Biology/Biological Sciences, General, 'total_graduates': 21, 'pct_awards': 0.03}, {'rank': 9, 'cipcode': 11.0103, 'cip_name': Information Technology, 'total_graduates': 21, 'pct_awards': 0.03}, {'rank': 10, 'cipcode': 13.1312, 'cip_name': Music Teacher Education, 'total_graduates': 17, 'pct_awards': 0.02}] │
# │     242042 │ [{'rank': 1, 'cipcode': 15.0399, 'cip_name': Electrical/Electronic Engineering Technologies/Technicians, Other, 'total_graduates': 16, 'pct_awards': 0.29}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │
# │     372921 │ [{'rank': 1, 'cipcode': 47.0201, 'cip_name': Heating, Air Conditioning, Ventilation and Refrigeration Maintenance Technology/Technician, 'total_graduates': 38, 'pct_awards': 0.46}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │     451149 │ [{'rank': 1, 'cipcode': 12.0402, 'cip_name': Barbering/Barber, 'total_graduates': 19, 'pct_awards': 0.41}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │
# │        ·   │                                                     ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │
# │        ·   │                                                     ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │
# │        ·   │                                                     ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │
# │     199856 │ [{'rank': 1, 'cipcode': 24.0101, 'cip_name': Liberal Arts and Sciences/Liberal Studies, 'total_graduates': 644, 'pct_awards': 0.25}, {'rank': 2, 'cipcode': 11.0103, 'cip_name': Information Technology, 'total_graduates': 414, 'pct_awards': 0.16}, {'rank': 3, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 206, 'pct_awards': 0.08}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │
# │     200226 │ [{'rank': 1, 'cipcode': 24.0102, 'cip_name': General Studies, 'total_graduates': 8, 'pct_awards': 0.13}, {'rank': 2, 'cipcode': 52.0299, 'cip_name': Business Administration, Management and Operations, Other, 'total_graduates': 8, 'pct_awards': 0.13}, {'rank': 3, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 6, 'pct_awards': 0.1}, {'rank': 4, 'cipcode': 13.1202, 'cip_name': Elementary Education and Teaching, 'total_graduates': 5, 'pct_awards': 0.08}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │
# │     202152 │ [{'rank': 1, 'cipcode': 51.3901, 'cip_name': Licensed Practical/Vocational Nurse Training, 'total_graduates': 5, 'pct_awards': 0.5}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │     209603 │ [{'rank': 1, 'cipcode': 50.041, 'cip_name': Illustration, 'total_graduates': 8, 'pct_awards': 0.21}, {'rank': 2, 'cipcode': 50.0102, 'cip_name': Digital Arts, 'total_graduates': 6, 'pct_awards': 0.16}, {'rank': 3, 'cipcode': 50.0409, 'cip_name': Graphic Design, 'total_graduates': 5, 'pct_awards': 0.13}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │
# │     210775 │ [{'rank': 1, 'cipcode': 51.0, 'cip_name': Health Services/Allied Health/Health Sciences, General, 'total_graduates': 27, 'pct_awards': 0.13}, {'rank': 2, 'cipcode': 43.0103, 'cip_name': Criminal Justice/Law Enforcement Administration, 'total_graduates': 20, 'pct_awards': 0.1}, {'rank': 3, 'cipcode': 52.0201, 'cip_name': Business Administration and Management, General, 'total_graduates': 19, 'pct_awards': 0.09}, {'rank': 4, 'cipcode': 52.0206, 'cip_name': Non-Profit/Public/Organizational Management, 'total_graduates': 17, 'pct_awards': 0.08}, {'rank': 5, 'cipcode': 31.0504, 'cip_name': Sport and Fitness Administration/Management, 'total_graduates': 12, 'pct_awards': 0.06}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# │     222628 │ [{'rank': 1, 'cipcode': 30.9999, 'cip_name': Multi-/Interdisciplinary Studies, Other, 'total_graduates': 21, 'pct_awards': 0.21}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │
# │     225371 │ [{'rank': 1, 'cipcode': 48.0508, 'cip_name': Welding Technology/Welder, 'total_graduates': 71, 'pct_awards': 0.24}, {'rank': 2, 'cipcode': 24.0102, 'cip_name': General Studies, 'total_graduates': 67, 'pct_awards': 0.23}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │
# │     228158 │ [{'rank': 1, 'cipcode': 24.0102, 'cip_name': General Studies, 'total_graduates': 113, 'pct_awards': 0.15}, {'rank': 2, 'cipcode': 48.0508, 'cip_name': Welding Technology/Welder, 'total_graduates': 88, 'pct_awards': 0.12}, {'rank': 3, 'cipcode': 47.0605, 'cip_name': Diesel Mechanics Technology/Technician, 'total_graduates': 44, 'pct_awards': 0.06}, {'rank': 4, 'cipcode': 11.0101, 'cip_name': Computer and Information Sciences, General, 'total_graduates': 36, 'pct_awards': 0.05}, {'rank': 5, 'cipcode': 50.0402, 'cip_name': Commercial and Advertising Art, 'total_graduates': 34, 'pct_awards': 0.05}, {'rank': 6, 'cipcode': 47.0604, 'cip_name': Automobile/Automotive Mechanics Technology/Technician, 'total_graduates': 33, 'pct_awards': 0.04}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# │     234377 │ [{'rank': 1, 'cipcode': 24.0101, 'cip_name': Liberal Arts and Sciences/Liberal Studies, 'total_graduates': 53, 'pct_awards': 0.25}, {'rank': 2, 'cipcode': 46.0302, 'cip_name': Electrician, 'total_graduates': 48, 'pct_awards': 0.22}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# │     236753 │ [{'rank': 1, 'cipcode': 24.0101, 'cip_name': Liberal Arts and Sciences/Liberal Studies, 'total_graduates': 177, 'pct_awards': 0.33}, {'rank': 2, 'cipcode': 51.081, 'cip_name': Emergency Care Attendant (EMT Ambulance), 'total_graduates': 69, 'pct_awards': 0.13}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │
# ├────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 3155 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
majors_df = majors.to_df()
majors_df.to_json('majors.jsonl', orient='records', lines=True)
